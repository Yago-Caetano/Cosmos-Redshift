# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt
from sklearn import metrics

# %%
data = pd.read_csv('sample_dataset.csv',decimal=",")
#data = data.tail(100) #use only the last 100 rows

data = data.iloc[49:149]

# %%
df_novo = data[['temperature', 'humidity', 'cracked']]

df_novo = df_novo.dropna(how='all',axis=0)


df_novo
# Out:
#             temperature           humidity  cracked
# 49   25.340425531914892  50.09574468085106      259
# 50   28.869473684210536  76.30526315789474      254
# 51   29.182105263157897  75.56842105263158      294
# 52   28.084374999999998  79.60416666666667      255
# 53    25.83020833333333           84.03125      248
# ..                  ...                ...      ...
# 144  28.871428571428574  66.03571428571429      342
# 145  27.906896551724135  83.39080459770115      266
# 146  27.290909090909096   78.5909090909091      299
# 147   25.34583333333333             80.875      309
# 148  26.157291666666666  91.13541666666667      301
#
# [100 rows x 3 columns]

# %%
from sklearn.preprocessing import StandardScaler



#Dados foram normalizados
padronizador = StandardScaler()
padronizador.fit(df_novo)
std_dt = padronizador.transform(df_novo)
std_dt = pd.DataFrame(data = std_dt,columns=df_novo.keys())

# %%
import seaborn as sns

matriz_correlacao = std_dt.corr()
plt.figure(figsize=(5, 5)) # width and height in inches
sns.heatmap(matriz_correlacao, annot = True, fmt = ".2f")
# Out:
# <Axes: >
